# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Input, MultiHeadAttention, LayerNormalization
# Out:
# 2024-12-27 15:08:40.547710: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-27 15:08:40.551030: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-27 15:08:40.559035: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735291420.571775   71217 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735291420.575421   71217 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
window_size = 30
lstm_units = 50
attention_heads = 2

# %%
# Loading and Preprocessing data
df = pd.read_csv('sanima.csv')
df = df.drop(['Percent Change', 'Symbol'], axis = 1)
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by="Date", ascending=True).reset_index(drop=True)
df.head()
# Out:
#         Date   Open   High    Low  Close     Volume
# 0 2019-12-29  314.0  314.0  311.0  311.0   6,143.00
# 1 2019-12-30  310.0  313.0  310.0  313.0  14,227.00
# 2 2019-12-31  313.0  315.0  312.0  313.0  15,113.00
# 3 2020-01-01  314.0  314.0  312.0  313.0   5,127.00
# 4 2020-01-02  311.0  313.0  311.0  313.0  11,998.00

# %%
df['Volume'] = df['Volume'].str.replace(',', '').astype(float)
price_columns = ['Open', 'High', 'Low', 'Close']
for col in price_columns: 
    df[col] = df[col].astype(float)

df.head()
# Out:
#         Date   Open   High    Low  Close   Volume
# 0 2019-12-29  314.0  314.0  311.0  311.0   6143.0
# 1 2019-12-30  310.0  313.0  310.0  313.0  14227.0
# 2 2019-12-31  313.0  315.0  312.0  313.0  15113.0
# 3 2020-01-01  314.0  314.0  312.0  313.0   5127.0
# 4 2020-01-02  311.0  313.0  311.0  313.0  11998.0

# %%
#Technical Indicators
"""A rising moving average indicates that the security is in an uptrend, while a declining moving average indicates a downtrend."""
import matplotlib.pyplot as plt

# Calculate the 20-period and 50-period moving averages
df['MA20'] = df['Close'].rolling(window=20).mean()
df['MA50'] = df['Close'].rolling(window=50).mean()

# Calculate the slope (rate of change) for MA20 and MA50 over 1 day
df['MA20_Slope'] = df['MA20'].diff()  # Daily change for MA20
df['MA50_Slope'] = df['MA50'].diff()  # Daily change for MA50

# Plotting the data
plt.figure(figsize=(14, 10))

# Subplot for Close price and Moving Averages
plt.subplot(3, 1, 1)
plt.plot(df['Date'], df['Close'], label='Close', color='blue')
plt.plot(df['Date'], df['MA20'], label='MA20', color='red', linestyle='--')
plt.plot(df['Date'], df['MA50'], label='MA50', color='green', linestyle='--')
plt.title('Stock Price and Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Subplot for MA20 slope and MA50 slope
plt.subplot(3, 1, 2)
plt.plot(df['Date'], df['MA20_Slope'], label='MA20 Slope', color='purple', linestyle='--', linewidth=1.5)
plt.plot(df['Date'], df['MA50_Slope'], label='MA50 Slope', color='orange', linestyle='--', linewidth=1.5)
plt.title('Moving Averages Slope')
plt.xlabel('Date')
plt.ylabel('Slope (Rate of Change)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
#                        Date      Open      High       Low     Close    Volume  \
# Date               1.000000 -0.531568 -0.533622 -0.533788 -0.533872 -0.041558
# Open              -0.531568  1.000000  0.997919  0.998145  0.996313  0.495911
# High              -0.533622  0.997919  1.000000  0.997758  0.998351  0.515802
# Low               -0.533788  0.998145  0.997758  1.000000  0.998352  0.491035
# Close             -0.533872  0.996313  0.998351  0.998352  1.000000  0.505996
# Volume            -0.041558  0.495911  0.515802  0.491035  0.505996  1.000000
# MA20              -0.554424  0.973271  0.970489  0.973408  0.971015  0.400040
# MA50              -0.584445  0.928247  0.924813  0.928399  0.925868  0.314151
# MACD              -0.019652  0.291042  0.300126  0.291624  0.296978  0.500006
# Signal_Line       -0.017095  0.312739  0.318778  0.312398  0.314872  0.456841
# MACD_Slope        -0.006673 -0.038885 -0.015093 -0.024351 -0.000864  0.215164
# ...

# %%
import matplotlib.pyplot as plt

# Calculate MACD and Signal Line
exp1 = df['Close'].ewm(span=12, adjust=False).mean()
exp2 = df['Close'].ewm(span=26, adjust=False).mean()
df['MACD'] = exp1 - exp2
df['Signal_Line'] = df['MACD'].ewm(span=9, adjust=False).mean()

# Calculate the slope (rate of change) for MACD and Signal Line over 1 day (or other time period)
df['MACD_Slope'] = df['MACD'].diff()  # Calculate daily change for MACD
df['Signal_Line_Slope'] = df['Signal_Line'].diff()  # Calculate daily change for Signal Line

# Plotting the data
plt.figure(figsize=(14, 10))

# Subplot for Close price and MACD
plt.subplot(3, 1, 2)
plt.plot(df['Date'], df['Close'], label='Close Price', color='blue', linewidth=1.5)
plt.plot(df['Date'], df['MACD'], label='MACD', color='purple')
plt.plot(df['Date'], df['Signal_Line'], label='Signal Line', color='orange', linestyle='--', linewidth=2.5)
plt.title('Stock Price and MACD')
plt.xlabel('Date')
plt.ylabel('MACD Values')
plt.legend()
plt.grid(True)

# Subplot for MACD slope and Signal Line slope
plt.subplot(3, 1, 3)
plt.plot(df['Date'], df['MACD_Slope'], label='MACD Slope', color='green', linestyle='--', linewidth=1.5)
plt.plot(df['Date'], df['Signal_Line_Slope'], label='Signal Line Slope', color='red', linestyle='--', linewidth=1.5)
plt.title('MACD and Signal Line Slope')
plt.xlabel('Date')
plt.ylabel('Slope (Rate of Change)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
#RSI calculation and plotting
import matplotlib.pyplot as plt

# Calculate RSI (14-period)
delta = df['Close'].diff()
gain = delta.where(delta > 0, 0)
loss = -delta.where(delta < 0, 0)

# Calculate the average gain and average loss over 14 periods
avg_gain = gain.rolling(window=14).mean()
avg_loss = loss.rolling(window=14).mean()

# Calculate the relative strength (RS)
rs = avg_gain / avg_loss

# Calculate the RSI
df['RSI'] = 100 - (100 / (1 + rs))

# Calculate the slope (rate of change) for RSI over 1 day
df['RSI_Slope'] = df['RSI'].diff()  # Daily change for RSI

# Plotting the data
plt.figure(figsize=(14, 10))

# Subplot for Close price, Moving Averages, and RSI
plt.subplot(3, 1, 1)
plt.plot(df['Date'], df['Close'], label='Close', color='blue')
plt.plot(df['Date'], df['MA20'], label='MA20', color='red', linestyle='--')
plt.plot(df['Date'], df['MA50'], label='MA50', color='green', linestyle='--')
plt.title('Stock Price and Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Subplot for RSI and its Slope
plt.subplot(3, 1, 2)
plt.plot(df['Date'], df['RSI'], label='RSI', color='purple', linestyle='-', linewidth=1.5)
plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI Values')
plt.legend()
plt.grid(True)

# Subplot for RSI Slope
plt.subplot(3, 1, 3)
plt.plot(df['Date'], df['RSI_Slope'], label='RSI Slope', color='orange', linestyle='--', linewidth=1.5)
plt.title('RSI Slope (Rate of Change)')
plt.xlabel('Date')
plt.ylabel('Slope (Rate of Change)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
df.head(50)
# Out:
#          Date   Open   High    Low  Close    Volume    MA20    MA50  \
# 0  2019-12-29  314.0  314.0  311.0  311.0    6143.0     NaN     NaN
# 1  2019-12-30  310.0  313.0  310.0  313.0   14227.0     NaN     NaN
# 2  2019-12-31  313.0  315.0  312.0  313.0   15113.0     NaN     NaN
# 3  2020-01-01  314.0  314.0  312.0  313.0    5127.0     NaN     NaN
# 4  2020-01-02  311.0  313.0  311.0  313.0   11998.0     NaN     NaN
# 5  2020-01-05  313.0  321.0  313.0  318.0   15644.0     NaN     NaN
# 6  2020-01-06  321.0  327.0  321.0  326.0   28001.0     NaN     NaN
# 7  2020-01-07  331.0  338.0  327.0  334.0   59699.0     NaN     NaN
# 8  2020-01-08  337.0  337.0  327.0  327.0   37066.0     NaN     NaN
# 9  2020-01-09  327.0  333.0  325.0  330.0   21136.0     NaN     NaN
# 10 2020-01-12  335.0  341.0  332.0  341.0   31499.0     NaN     NaN
# 11 2020-01-13  342.0  350.0  336.0  346.0   46070.0     NaN     NaN
# 12 2020-01-14  346.0  346.0  339.0  343.0   32388.0     NaN     NaN
# ...

# %%
import matplotlib.pyplot as plt

# Calculate the Pivot Point (Standard) for each day
df['Pivot_Point'] = (df['High'] + df['Low'] + df['Close']) / 3

# Plotting the data
plt.figure(figsize=(14, 10))

# Plotting the Close price and Pivot Point
plt.plot(df['Date'], df['Close'], label='Close Price', color='blue', linewidth=1.5)
plt.plot(df['Date'], df['Pivot_Point'], label='Pivot Point', color='orange', linestyle='--', linewidth=2)

# Adding titles and labels
plt.title('Stock Price and Pivot Point')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
